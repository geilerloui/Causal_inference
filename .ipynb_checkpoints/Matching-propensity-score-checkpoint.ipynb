# %% [markdown]
# # Matching
#
# * https://www.youtube.com/watch?v=vT3oGupOSyQ

# %%
#install packages
install.packages("tableone")
install.packages("Matching")

# %%
library(tableone)
# Out:
# Error in library(tableone): there is no package called ‘tableone’
# Traceback:
#
# 1. library(tableone)

# %%
library(ggplot2)

# %%
install.packages("tableone")
# Out:
# also installing the dependency ‘e1071’
#
# Warning message in install.packages("tableone"):
# “installation of package ‘e1071’ had non-zero exit status”Warning message in install.packages("tableone"):
# “installation of package ‘tableone’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#load packages
#library(tableone)
library(Matching)

#read in data
load(url("http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/rhc.sav"))
# Out:
# Warning message:
# “package ‘Matching’ was built under R version 3.6.1”Loading required package: MASS
# ##
# ##  Matching (Version 4.9-6, Build Date: 2019-04-07)
# ##  See http://sekhon.berkeley.edu/matching for additional documentation.
# ##  Please cite software as:
# ##   Jasjeet S. Sekhon. 2011. ``Multivariate and Propensity Score Matching
# ##   Software with Automated Balance Optimization: The Matching package for R.''
# ##   Journal of Statistical Software, 42(7): 1-52.
# ##

# %%
head(rhc)
# Out:
#   cat1              cat2          ca  sadmdte dschdte dthdte lstctdte death
# 1 COPD              NA            Yes 11142   11151      NA  11382    No
# 2 MOSF w/Sepsis     NA            No  11799   11844   11844  11844    Yes
# 3 MOSF w/Malignancy MOSF w/Sepsis Yes 12083   12143      NA  12400    No
# 4 ARF               NA            No  11146   11183   11183  11182    Yes
# 5 MOSF w/Sepsis     NA            No  12035   12037   12037  12036    Yes
# 6 COPD              NA            No  12389   12396      NA  12590    No
#   cardiohx chfhx ... meta hema seps trauma ortho adld3p urin1 race  income
# 1 0        0     ... No   No   No   No     No     0       NA  white Under $11k
# 2 1        1     ... No   No   Yes  No     No    NA     1437  white Under $11k
# 3 0        0     ... No   No   No   No     No    NA      599  white $25-$50k
# 4 0        0     ... No   No   No   No     No    NA       NA  white $11-$25k
# ...

# %% [markdown]
# > We wish to convert some of the character variable into numeric variables

# %%
#treatment variables is swang1
#x variables that we will use
#cat1: primary disease category
#age
#sex
#meanbp1: mean blood pressure

#create a data set with just these variables, for simplicity
ARF<-as.numeric(rhc$cat1=='ARF')
CHF<-as.numeric(rhc$cat1=='CHF')
Cirr<-as.numeric(rhc$cat1=='Cirrhosis')
colcan<-as.numeric(rhc$cat1=='Colon Cancer')
Coma<-as.numeric(rhc$cat1=='Coma')
COPD<-as.numeric(rhc$cat1=='COPD')
lungcan<-as.numeric(rhc$cat1=='Lung Cancer')
MOSF<-as.numeric(rhc$cat1=='MOSF w/Malignancy')
sepsis<-as.numeric(rhc$cat1=='MOSF w/Sepsis')
female<-as.numeric(rhc$sex=='Female')
died<-as.numeric(rhc$death=='Yes')
age<-rhc$age
treatment<-as.numeric(rhc$swang1=='RHC')
meanbp1<-rhc$meanbp1

#new dataset
mydata<-cbind(ARF,CHF,Cirr,colcan,Coma,lungcan,MOSF,sepsis,
              age,female,meanbp1,treatment,died)
mydata<-data.frame(mydata)

#covariates we will use (shorter list than you would use in practice)
xvars<-c("ARF","CHF","Cirr","colcan","Coma","lungcan","MOSF","sepsis",
         "age","female","meanbp1")
# Out:
# Error in CreateTableOne(vars = xvars, strata = "treatment", data = mydata, : could not find function "CreateTableOne"
# Traceback:

# %% [markdown]
# > We are only interested by rows where the SMD is greater than one

# %%
#look at a table 1
table1<- CreateTableOne(vars=xvars,strata="treatment", data=mydata, test=FALSE)
## include standardized mean difference (SMD)
# SMD=True, standardized differences = truea
print(table1,smd=TRUE)

# %%
############################################
#do greedy matching on Mahalanobis distance
############################################

# M: if you want pair matching (=1)
greedymatch<-Match(Tr=treatment,M=1,X=mydata[xvars],replace=FALSE)
# matched will get the ID of those who are treated and control
matched<-mydata[unlist(greedymatch[c("index.treated","index.control")]), ]

# %% [markdown]
# > We get exactly 2186: 0 , 2186: 1 and the SMD is <0.001 or 0.005 (the biggest) --> we did a great job at matching

# %%
#get table 1 for matched data with standardized differences
# test=False - we are not interested in statistical testinga
matchedtab1<-CreateTableOne(vars=xvars, strata ="treatment", 
                            data=matched, test = FALSE)
print(matchedtab1, smd = TRUE)

# %% [markdown]
# > We see that the point estimate is 0.05 with a confidence interval of 95%.
# > it is the difference in probability of death if everyone received RHC versus
# > if no one received RHC is 0.05 (i.e. higher risk of death in RHC group)

# %%
#outcome analysis
y_trt<-matched$died[matched$treatment==1]
y_con<-matched$died[matched$treatment==0]

#pairwise difference
diffy<-y_trt - y_con

#paired t-test
t.test(diffy)
# Out:
# 	One Sample t-test
#
# data:  diffy
# t = 3.9289, df = 2183, p-value = 8.799e-05
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  0.02706131 0.08099730
# sample estimates:
# mean of x
# 0.0540293

# %% [markdown]
# > We can also carry out a McNemar test, in the table: 394=the control died when the treated did not

# %%
#McNemar test
table(y_trt,y_con)

mcnemar.test(matrix(c(973,513,395,303),2,2))
# Out:
#      y_con
# y_trt   0   1
#     0 303 395
#     1 513 973
# 	McNemar's Chi-squared test with continuity correction
#
# data:  matrix(c(973, 513, 395, 303), 2, 2)
# McNemar's chi-squared = 15.076, df = 1, p-value = 0.0001033

# %% [markdown]
# ## Propensity scores matching

# %%
##########################
#propensity score matching
#########################

#read in data
load(url("http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/rhc.sav"))

aps <- rhc$aps1

mydata<-cbind(ARF,CHF,Cirr,colcan,Coma,lungcan,MOSF,sepsis,
              age,female,meanbp1,aps, treatment,died)
mydata<-data.frame(mydata)

# %%
#fit a propensity score model. logistic regression

psmodel<-glm(treatment~ARF+CHF+Cirr+colcan+Coma+lungcan+MOSF+
               sepsis+age+female+meanbp1+aps,
    family=binomial(),data=mydata)

#show coefficients etc
summary(psmodel)
#create propensity score
pscore<-psmodel$fitted.values
# Out:
# Call:
# glm(formula = treatment ~ ARF + CHF + Cirr + colcan + Coma +
#     lungcan + MOSF + sepsis + age + female + meanbp1 + aps, family = binomial(),
#     data = mydata)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0498  -0.9602  -0.6190   1.1289   2.3878
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -1.9460154  0.2321291  -8.383  < 2e-16 ***
# ARF          1.2252930  0.1495511   8.193 2.54e-16 ***
# CHF          1.8905642  0.1735687  10.892  < 2e-16 ***
# Cirr         0.4334062  0.2203366   1.967  0.04918 *
# colcan       0.0481566  1.1242894   0.043  0.96583
# Coma         0.6842545  0.1878333   3.643  0.00027 ***
# lungcan      0.1984600  0.5055005   0.393  0.69461
# MOSF         1.0177797  0.1807159   5.632 1.78e-08 ***
# sepsis       1.8402456  0.1561589  11.784  < 2e-16 ***
# age         -0.0030469  0.0017462  -1.745  0.08101 .
# female      -0.1390768  0.0590139  -2.357  0.01844 *
# ...

# %% [markdown]
# > we look above, for female=-0.13 means female are less likely to be treated than mean
# > we can look at other predictors to see who is likely to be treated

# %%
library(MatchIt)

# use matchit for propensity score, nearest neighbor matching
m.out <- matchit(treatment~ARF+CHF+Cirr+colcan+Coma+lungcan+MOSF+
               sepsis+age+female+meanbp1+aps, data=mydata, method = "nearest")

summary(m.out)
# Out:
# Call:
# matchit(formula = treatment ~ ARF + CHF + Cirr + colcan + Coma +
#     lungcan + MOSF + sepsis + age + female + meanbp1 + aps, data = mydata,
#     method = "nearest")
#
# Summary of balance for all data:
#          Means Treated Means Control SD Control Mean Diff eQQ Med eQQ Mean
# distance        0.4568        0.3341     0.1628    0.1227  0.1327   0.1228
# ARF             0.4162        0.4452     0.4971   -0.0290  0.0000   0.0288
# CHF             0.0957        0.0696     0.2544    0.0261  0.0000   0.0261
# Cirr            0.0224        0.0493     0.2165   -0.0268  0.0000   0.0266
# colcan          0.0005        0.0017     0.0411   -0.0012  0.0000   0.0014
# Coma            0.0435        0.0960     0.2947   -0.0525  0.0000   0.0527
# lungcan         0.0023        0.0096     0.0974   -0.0073  0.0000   0.0073
# MOSF            0.0723        0.0679     0.2516    0.0045  0.0000   0.0046
# sepsis          0.3205        0.1484     0.3556    0.1721  0.0000   0.1722
# ...

# %% [markdown]
# > It is broken up into four different sections:
# * there are no unmatched treatment units, everybody in the treatement was match to someone in the control
# * the two plots in the middle should look rather similar cause we matched
# * the last one: people in the control who got no match

# %%
# propensity score plots
plot(m.out, type="jitter")
# Out:
# [1] "To identify the units, use first mouse button; to stop, use second."
# integer(0)
# Plot with title “Distribution of Propensity Scores”

# %% [markdown]
# > How to read the plots ?
# * we look at the Raw Treated vs control: we notice that there is more distribution on the left of the Raw Control
# * On the matching side the shape are a lot more similar

# %%
plot(m.out, type="hist")
# Out:
# Plot with title “Matched Control”

# %%
#do greedy matching on logit(PS) using Match with a caliper

logit <- function(p) {log(p)-log(1-p)}
psmatch<-Match(Tr=mydata$treatment,M=1,X=logit(pscore),replace=FALSE,caliper=.2)
matched<-mydata[unlist(psmatch[c("index.treated","index.control")]), ]
xvars<-c("ARF","CHF","Cirr","colcan","Coma","lungcan","MOSF","sepsis",
         "age","female","meanbp1")

#get standardized differences
matchedtab1<-CreateTableOne(vars=xvars, strata ="treatment", 
                            data=matched, test = FALSE)
print(matchedtab1, smd = TRUE)

#outcome analysis
y_trt<-matched$died[matched$treatment==1]
y_con<-matched$died[matched$treatment==0]

#pairwise difference
diffy<-y_trt-y_con

#paired t-test
t.test(diffy)
